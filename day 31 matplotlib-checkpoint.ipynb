# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # Draw pie cart to track down home expenses

# %%
exp_vals=[1400,600,300,400,250]
exp_labels=['Home Rent','Food','phone/Internet Bill','Car ','Other Utilities']
plt.pie(exp_vals,labels=exp_labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x22dec510c50>,
# ...
#  [Text(0.0877647387286345, 1.096493205923272, 'Home Rent'),
#   Text(-0.9760873147572474, -0.5072016896363679, 'Food'),
#   Text(-0.14599818555064192, -1.090268099971709, 'phone/Internet Bill'),
#   Text(0.6322660548177697, -0.9001331212243961, 'Car '),
#   Text(1.0612446267621083, -0.2894129267474999, 'Other Utilities')])

# %% [markdown]
# plt.pie(exp_vals,labels=exp_labels,shadow=True)
# plt.axis('equal')
# plt.show()
# plt.savefig('1.png')

# %% [markdown]
# # show percentage for every pie .specif radius to increase chart size

# %%
plt.axis('equal')
plt.pie(exp_vals,labels=exp_labels,shadow=True,autopct='%1.1f%%',radius=1.5)
plt.show()

# %% [markdown]
# # Explode

# %%
plt.axis('equal')
plt.pie(exp_vals,labels=exp_labels,shadow=True,autopct='%1.1f%%',radius=1.5,explode=[0,0,0,0.1,0.6])
plt.show()

# %% [markdown]
# #  counterclock and angle properties

# %%
plt.axis('equal')
plt.pie(exp_vals,labels=exp_labels,shadow=True,autopct='%1.1f%%',radius=1.5,explode=[0,0,0,0.1,0.6],counterclock=False,startangle=45)
plt.show()

# %%
plt.axis('equal')
plt.pie(exp_vals,labels=exp_labels,shadow=True,autopct='%1.1f%%',radius=1.5,explode=[0,0,0,0.1,0.6],counterclock=True,startangle=45)
plt.show()

# %%
import seaborn as sns
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import pandas as pd
import numpy as np

# %%
Series= pd.Series ([0.2]*5, index=['a','b','c','d','e'],name='plot')
Series
# Out:
# a    0.2
# b    0.2
# c    0.2
# d    0.2
# e    0.2
# Name: plot, dtype: float64

# %%
Series.plot.pie()
# Out:
# <Axes: ylabel='plot'>

# %%
x=iris.iloc[:,:-1]
d=x.iloc[0]
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
d=x.iloc[0]

# %%
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize=(5,5),fontsize=10,autopct='%.0f%%')
# Out:
# <Axes: ylabel='0'>

# %%
A=x.head(3).T
A
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
A.plot.pie(subplots=True,figsize=(45,45),fontsize=30,autopct='%.1f%%',)
# Out:
# array([<Axes: ylabel='0'>, <Axes: ylabel='1'>, <Axes: ylabel='2'>],
#       dtype=object)
